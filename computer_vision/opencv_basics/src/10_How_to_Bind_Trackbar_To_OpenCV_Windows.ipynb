# %%
import numpy as np
import cv2 as cv

# %%
def nothing(x):
    print(x)

# Create a black image, a window
img = np.zeros((300,512,3), np.uint8)
cv.namedWindow('image')                       # namedWindow is used to help in which window you want to carry an operation

cv.createTrackbar('B', 'image', 0, 255, nothing)        # In the image window we want to add 'B' Trackbar 
cv.createTrackbar('G', 'image', 0, 255, nothing)        # 0--> initial value of trackbar, 255--> max. value of trackbar
cv.createTrackbar('R', 'image', 0, 255, nothing)        # 'nothing' will be called whenever the trackbar is updated

while(1):
    cv.imshow('image',img)
    k = cv.waitKey(1) & 0xFF
    if k == 27:
        break

cv.destroyAllWindows()
# Out:
# 5
# 10
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 10
# 15
# 18
# 22
# 24
# 27
# 30
# 33
# 37
# 40
# 42
# 45
# 47
# 48
# 49
# 50
# 51
# 52
# 53
# 55
# 57
# 59
# 60
# 61
# 62
# 63
# 64
# 65
# 66
# 68
# 69
# 70
# 71
# 73
# 75
# 78
# 80
# 84
# 87
# 88
# 91
# 93
# 96
# 98
# 101
# 103
# 104
# 105
# 106
# 107
# 108
# 109
# 111
# 112
# 113
# 115
# 116
# 118
# 119
# 120
# 121
# 122
# 124
# 125
# 126
# 128
# 129
# 131
# 133
# 134
# 135
# 136
# 137
# 138
# 139
# 138
# 136
# 134
# 132
# 131
# 129
# 128
# 126
# 124
# 121
# 119
# 118
# 117
# 116
# 112
# 108
# 106
# 101
# 96
# 89
# 82
# 76
# 69
# 62
# 58
# 55
# 50
# 49
# 48
# 46
# 44
# 41
# 38
# 35
# 33
# 32
# 30
# 29
# 28
# 27
# 26
# 25
# 24
# 23
# 22
# 21
# 19
# 18
# 17
# 14
# 13
# 11
# 9
# 8
# 6
# 5
# 4
# 2
# 1
# 0

# %%
def nothing(x):
    print(x)

# Create a black image, a window
img = np.zeros((300,512,3), np.uint8)
cv.namedWindow('image')                       # namedWindow is used to help in which window you want to carry an operation

cv.createTrackbar('B', 'image', 0, 255, nothing)        # In the image window we want to add 'B' Trackbar 
cv.createTrackbar('G', 'image', 0, 255, nothing)        # 0--> lower range of trackbar, 255--> upper range of trackbar
cv.createTrackbar('R', 'image', 0, 255, nothing)        # 'nothing' will be called whenever the trackbar is updated

switch = '0 : OFF\n 1 : ON'
cv.createTrackbar(switch, 'image', 0, 1, nothing)

while(1):
    cv.imshow('image',img)
    k = cv.waitKey(1) & 0xFF
    if k == 27:                                     # '27'--> stands for escape key
        break

    b = cv.getTrackbarPos('B', 'image')             # track position of trackbar 'B' which is present in window -->'image'
    g = cv.getTrackbarPos('G', 'image')
    r = cv.getTrackbarPos('R', 'image')
    s = cv.getTrackbarPos(switch, 'image')

    if s == 0:
       img[:] = 0
    else:
       img[:] = [b, g, r]


cv.destroyAllWindows()
# Out:
# 1
# 51
# 102
# 51
# 51
# 102

# %%
import numpy as np
import cv2 as cv

def nothing(x):
    print(x)

# Create a black image, a window
cv.namedWindow('image')

cv.createTrackbar('CP', 'image', 10, 400, nothing)   # 'CP' is the name of the trackbar & it will present in image window

switch = 'color/gray'
cv.createTrackbar(switch, 'image', 0, 1, nothing)

while(1):
    img = cv.imread('C:/Users/piyus/All programming files/Computer_Vision/data/lena.jpg')
    pos = cv.getTrackbarPos('CP', 'image')                                    # it will track the position of trackbar CP
    font = cv.FONT_HERSHEY_SIMPLEX
    cv.putText(img, str(pos), (50, 150), font, 6, (0, 0, 255), 10)
    # the value of trackbar 'CP' will act as 'text' element to be printed on the image
    
    k = cv.waitKey(1) & 0xFF
    if k == 27:
        break

    s = cv.getTrackbarPos(switch, 'image')

    if s == 0:
       pass
    else:
       img = cv.cvtColor(img, cv.COLOR_BGR2GRAY)                     # converting scalar to scalar

    img = cv.imshow('image',img)

cv.destroyAllWindows()
# Out:
# 11
# 12
# 15
# 17
# 19
# 21
# 24
# 27
# 29
# 34
# 35
# 36
# 39
# 41
# 43
# 44
# 46
# 47
# 48
# 50
# 56
# 61
# 63
# 64
# 65
# 66
# 68
# 69
# 68
# 66
# 65
# 64
# 62
# 60
# 59
# 57
# 56
# 54
# 52
# 50
# 47
# 43
# 37
# 34
# 27
# 24
# 16
# 10
# 1
# 0
# 1
# 2
# 3
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# 14
# 15
# 16
# 17
# 18
# 19
# 20
# 21
# 24
# 25
# 26
# 27
# 28
# 29
# 30
# 32
# 33
# 34
# 35
# 36
# 37
# 38
# 39
# 41
# 42
# 43
# 44
# 46
# 48
# 51
# 52
# 55
# 56
# 59
# 60
# 62
# 63
# 65
# 66
# 69
# 70
# 71
# 72
# 74
# 75
# 77
# 78
# 79
# 80
# 82
# 83
# 85
# 86
# 85
# 83
# 82
# 81
# 79
# 78
# 75
# 73
# 72
# 69
# 66
# 65
# 64
# 62
# 61
# 60
# 59
# 56
# 55
# 53
# 51
# 48
# 47
# 46
# 44
# 42
# 41
# 38
# 37
# 35
# 34
# 32
# 30
# 28
# 27
# 24
# 21
# 20
# 19
# 17
# 16
# 14
# 12
# 10
# 9
# 7
# 6
# 3
# 2
# 1
# 0
# 1
# 2
# 3
# 5
# 6
# 7
# 8
# 10
# 11
# 12
# 14
# 15
# 16
# 18
# 19
# 20
# 21
# 23
# 24
# 25
# 27
# 28
# 29
# 30
# 33
# 34
# 35
# 37
# 38
# 39
# 41
# 42
# 43
# 44
# 45
# 46
# 48
# 47
# 46
# 45
# ...
